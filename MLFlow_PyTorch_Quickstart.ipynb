# %% [markdown]
# ### Install Dependencies

# %%
# %pip install mlflow torchmetrics torchinfo
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Collecting mlflow
#   Downloading mlflow-2.22.0-py3-none-any.whl.metadata (30 kB)
# Collecting torchmetrics
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Collecting mlflow-skinny==2.22.0 (from mlflow)
#   Downloading mlflow_skinny-2.22.0-py3-none-any.whl.metadata (31 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Jinja2<4,>=3.0 (from mlflow)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown<4,>=3.3 (from mlflow)
#   Using cached markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting matplotlib<4 (from mlflow)
#   Downloading matplotlib-3.10.3-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting numpy<3 (from mlflow)
#   Using cached numpy-2.2.5-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting pandas<3 (from mlflow)
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting pyarrow<20,>=4.0.0 (from mlflow)
#   Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting scipy<2 (from mlflow)
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading sqlalchemy-2.0.40-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from mlflow-skinny==2.22.0->mlflow)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading databricks_sdk-0.52.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading opentelemetry_api-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting packaging<25 (from mlflow-skinny==2.22.0->mlflow)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==2.22.0->mlflow)
#   Using cached protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==2.22.0->mlflow)
#   Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl.metadata (2.1 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==2.22.0->mlflow)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Collecting uvicorn<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.22.0->mlflow) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading google_auth-2.40.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.22.0->mlflow)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting Werkzeug>=3.1 (from Flask<4->mlflow)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting itsdangerous>=2.2 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.9 (from Flask<4->mlflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2<4,>=3.0->mlflow)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl.metadata (4.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow)
#   Using cached fonttools-4.57.0-cp310-cp310-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow)
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib<4->mlflow)
#   Using cached pillow-11.2.1-cp310-cp310-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-semantic-conventions==0.53b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pytz>=2020.1 (from pandas<3->mlflow)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3->mlflow)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow)
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow)
#   Using cached charset_normalizer-3.4.2-cp310-cp310-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting joblib>=1.2.0 (from scikit-learn<2->mlflow)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2->mlflow)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Downloading greenlet-3.2.1-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.2.2)
# Collecting sniffio>=1.1 (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==2.22.0->mlflow)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting torch>=2.0.0 (from torchmetrics)
#   Using cached torch-2.7.0-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow)
#   Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: setuptools in c:\users\reach\documents\ai\mlops\mlflow\.venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (65.5.0)
# Collecting filelock (from torch>=2.0.0->torchmetrics)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->torchmetrics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.0.0->torchmetrics)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting fsspec (from torch>=2.0.0->torchmetrics)
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->torchmetrics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading mlflow-2.22.0-py3-none-any.whl (29.0 MB)
#    ---------------------------------------- 0.0/29.0 MB ? eta -:--:--
#    ------------- -------------------------- 9.4/29.0 MB 49.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 21.5/29.0 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------- 29.0/29.0 MB 51.1 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.22.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 54.6 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading databricks_sdk-0.52.0-py3-none-any.whl (700 kB)
#    ---------------------------------------- 0.0/700.2 kB ? eta -:--:--
#    ---------------------------------------- 700.2/700.2 kB ? eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
# Downloading flask-3.1.0-py3-none-any.whl (102 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.40.1-py2.py3-none-any.whl (216 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markdown-3.8-py3-none-any.whl (106 kB)
# Downloading matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 55.7 MB/s eta 0:00:00
# Using cached numpy-2.2.5-cp310-cp310-win_amd64.whl (12.9 MB)
# Downloading opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
# Downloading pyarrow-19.0.1-cp310-cp310-win_amd64.whl (25.3 MB)
#    ---------------------------------------- 0.0/25.3 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/25.3 MB 114.7 MB/s eta 0:00:01
#    --- ------------------------------------ 2.1/25.3 MB 114.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 3.1/25.3 MB 6.8 MB/s eta 0:00:04
#    ------ --------------------------------- 4.2/25.3 MB 5.6 MB/s eta 0:00:04
#    ------ --------------------------------- 4.2/25.3 MB 5.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 11.3/25.3 MB 9.0 MB/s eta 0:00:02
#    --------------------- ------------------ 13.6/25.3 MB 10.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.7/25.3 MB 9.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.7/25.3 MB 9.5 MB/s eta 0:00:02
#    -------------------------- ------------- 16.8/25.3 MB 8.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.9/25.3 MB 8.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.9/25.3 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.5/25.3 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 25.3/25.3 MB 9.1 MB/s eta 0:00:00
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 54.6 MB/s eta 0:00:00
# Using cached PyYAML-6.0.2-cp310-cp310-win_amd64.whl (161 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp310-cp310-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------- ----------------------------- 10.7/41.3 MB 56.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 23.1/41.3 MB 56.2 MB/s eta 0:00:01
#    --------------------------------- ------ 34.9/41.3 MB 56.8 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 53.5 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlalchemy-2.0.40-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 115.5 MB/s eta 0:00:00
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ---------------------------------------- 0.0/961.5 kB ? eta -:--:--
#    --------------------------------------- 961.5/961.5 kB 46.6 MB/s eta 0:00:00
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Using cached fonttools-4.57.0-cp310-cp310-win_amd64.whl (2.2 MB)
# Downloading greenlet-3.2.1-cp310-cp310-win_amd64.whl (294 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Using cached pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached torch-2.7.0-cp310-cp310-win_amd64.whl (212.5 MB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 54.9 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Installing collected packages: pytz, mpmath, zipp, wrapt, waitress, urllib3, tzdata, typing-inspection, torchinfo, threadpoolctl, sympy, sqlparse, sniffio, smmap, pyyaml, pyparsing, pydantic-core, pyasn1, pyarrow, protobuf, pillow, packaging, numpy, networkx, MarkupSafe, markdown, kiwisolver, joblib, itsdangerous, idna, h11, greenlet, graphql-core, fsspec, fonttools, filelock, cycler, cloudpickle, click, charset-normalizer, certifi, cachetools, blinker, annotated-types, Werkzeug, uvicorn, sqlalchemy, scipy, rsa, requests, pydantic, pyasn1-modules, pandas, Mako, lightning-utilities, Jinja2, importlib_metadata, graphql-relay, gitdb, deprecated, contourpy, anyio, torch, starlette, scikit-learn, opentelemetry-api, matplotlib, graphene, google-auth, gitpython, Flask, docker, alembic, torchmetrics, opentelemetry-semantic-conventions, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
#
#    ----------------------------------------  0/80 [pytz]
#    ----------------------------------------  0/80 [pytz]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#     ---------------------------------------  1/80 [mpmath]
#    - --------------------------------------  2/80 [zipp]
#    - --------------------------------------  3/80 [wrapt]
#    -- -------------------------------------  4/80 [waitress]
#    -- -------------------------------------  4/80 [waitress]
#    -- -------------------------------------  4/80 [waitress]
#    -- -------------------------------------  5/80 [urllib3]
#    -- -------------------------------------  5/80 [urllib3]
#    -- -------------------------------------  5/80 [urllib3]
#    -- -------------------------------------  5/80 [urllib3]
#    -- -------------------------------------  5/80 [urllib3]
#    -- -------------------------------------  5/80 [urllib3]
#    --- ------------------------------------  6/80 [tzdata]
#    --- ------------------------------------  6/80 [tzdata]
#    ---- -----------------------------------  8/80 [torchinfo]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 10/80 [sympy]
#    ----- ---------------------------------- 11/80 [sqlparse]
#    ----- ---------------------------------- 11/80 [sqlparse]
#    ----- ---------------------------------- 11/80 [sqlparse]
#    ----- ---------------------------------- 11/80 [sqlparse]
#    ------ --------------------------------- 12/80 [sniffio]
#    ------ --------------------------------- 13/80 [smmap]
#    ------- -------------------------------- 14/80 [pyyaml]
#    ------- -------------------------------- 14/80 [pyyaml]
#    ------- -------------------------------- 14/80 [pyyaml]
#    ------- -------------------------------- 15/80 [pyparsing]
#    ------- -------------------------------- 15/80 [pyparsing]
#    -------- ------------------------------- 16/80 [pydantic-core]
#    -------- ------------------------------- 17/80 [pyasn1]
#    -------- ------------------------------- 17/80 [pyasn1]
#    -------- ------------------------------- 17/80 [pyasn1]
#    -------- ------------------------------- 17/80 [pyasn1]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 18/80 [pyarrow]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    --------- ------------------------------ 19/80 [protobuf]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 20/80 [pillow]
#   Attempting uninstall: packaging
#    ---------- ----------------------------- 20/80 [pillow]
#    ---------- ----------------------------- 21/80 [packaging]
#     Found existing installation: packaging 25.0
#    ---------- ----------------------------- 21/80 [packaging]
#     Uninstalling packaging-25.0:
#    ---------- ----------------------------- 21/80 [packaging]
#       Successfully uninstalled packaging-25.0
#    ---------- ----------------------------- 21/80 [packaging]
#    ---------- ----------------------------- 21/80 [packaging]
#    ---------- ----------------------------- 21/80 [packaging]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 22/80 [numpy]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
#    ----------- ---------------------------- 23/80 [networkx]
# ...
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.7.0+cu128 torchaudio-2.7.0+cu128 torchvision-0.22.0+cu128
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Required Packages

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchinfo import summary
from torchmetrics import Accuracy
from torchvision import datasets
from torchvision.transforms import ToTensor
import numpy as np

import mlflow
from mlflow.types import Schema, TensorSpec
from mlflow.models import ModelSignature

# %%
training_data = datasets.FashionMNIST(
  root="data",
  train=True,
  download=True,
  transform=ToTensor(),
)

test_data = datasets.FashionMNIST(
  root="data",
  train=False,
  download=True,
  transform=ToTensor(),
)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
print(f"Image size: {training_data[0][0].shape}")
print(f"Size of training dataset: {len(training_data)}")
print(f"Size of test dataset: {len(test_data)}")
# Out:
# Image size: torch.Size([1, 28, 28])
# Size of training dataset: 60000
# Size of test dataset: 10000

# %%
train_dataloader = DataLoader(training_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

# %%
class ImageClassifier(nn.Module):
  def __init__(self):
      super().__init__()
      self.model = nn.Sequential(
          nn.Conv2d(1, 8, kernel_size=3),
          nn.ReLU(),
          nn.Conv2d(8, 16, kernel_size=3),
          nn.ReLU(),
          nn.Flatten(),
          nn.LazyLinear(10),  # 10 classes in total.
      )

  def forward(self, x):
      return self.model(x)

# %% [markdown]
# ### Open a Terminal to start the MLFlow Tracking Server

# %%
! mlflow server --host 127.0.0.1 --port 8081
# Out:
# ^C
# INFO:waitress:Serving on http://127.0.0.1:8081
# WARNING:waitress.queue:Task queue depth is 1
# WARNING:waitress.queue:Task queue depth is 1
# Running the mlflow server failed. Please see the logs above for details.

# %% [markdown]
# ### Start the Tracking Server URI

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:8081")

# %% [markdown]
# ### Create a new MLflow Experiment

# %%
mlflow.set_experiment("/Experiments/mlflow-pytorch-quickstart")
# Out:
# 2025/05/09 19:40:59 INFO mlflow.tracking.fluent: Experiment with name '/Experiments/mlflow-pytorch-quickstart' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///c:/Users/reach/Documents/AI/MLOps/MLFlow/Projects/Logistic_Regression/mlruns/975146762046751879', creation_time=1746790859334, experiment_id='975146762046751879', last_update_time=1746790859334, lifecycle_stage='active', name='/Experiments/mlflow-pytorch-quickstart', tags={}>

# %%
# Get cpu or gpu for training.
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def train(dataloader, model, loss_fn, metrics_fn, optimizer, epoch):
  """Train the model on a single pass of the dataloader.

  Args:
      dataloader: an instance of `torch.utils.data.DataLoader`, containing the training data.
      model: an instance of `torch.nn.Module`, the model to be trained.
      loss_fn: a callable, the loss function.
      metrics_fn: a callable, the metrics function.
      optimizer: an instance of `torch.optim.Optimizer`, the optimizer used for training.
      epoch: an integer, the current epoch number.
  """
  model.train()
  for batch, (X, y) in enumerate(dataloader):
      X, y = X.to(device), y.to(device)

      pred = model(X)
      loss = loss_fn(pred, y)
      accuracy = metrics_fn(pred, y)

      # Backpropagation.
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      if batch % 100 == 0:
          loss, current = loss.item(), batch
          step = batch // 100 * (epoch + 1)
          mlflow.log_metric("loss", f"{loss:2f}", step=step)
          mlflow.log_metric("accuracy", f"{accuracy:2f}", step=step)
          print(f"loss: {loss:2f} accuracy: {accuracy:2f} [{current} / {len(dataloader)}]")

# %%
def evaluate(dataloader, model, loss_fn, metrics_fn, epoch):
  """Evaluate the model on a single pass of the dataloader.

  Args:
      dataloader: an instance of `torch.utils.data.DataLoader`, containing the eval data.
      model: an instance of `torch.nn.Module`, the model to be trained.
      loss_fn: a callable, the loss function.
      metrics_fn: a callable, the metrics function.
      epoch: an integer, the current epoch number.
  """
  num_batches = len(dataloader)
  model.eval()
  eval_loss, eval_accuracy = 0, 0
  with torch.no_grad():
      for X, y in dataloader:
          X, y = X.to(device), y.to(device)
          pred = model(X)
          eval_loss += loss_fn(pred, y).item()
          eval_accuracy += metrics_fn(pred, y)

  eval_loss /= num_batches
  eval_accuracy /= num_batches
  mlflow.log_metric("eval_loss", f"{eval_loss:2f}", step=epoch)
  mlflow.log_metric("eval_accuracy", f"{eval_accuracy:2f}", step=epoch)

  print(f"Eval metrics: Accuracy: {eval_accuracy:.2f}, Avg loss: {eval_loss:2f} ")

# %%
epochs = 3
loss_fn = nn.CrossEntropyLoss()
metric_fn = Accuracy(task="multiclass", num_classes=10).to(device)
model = ImageClassifier().to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %%
# Set the model signature
input_schema = Schema([TensorSpec(np.dtype(np.float32), (-1, 28, 28))])
output_schema = Schema([TensorSpec(np.dtype(np.float32), (-1, 10))])
signature = ModelSignature(inputs=input_schema, outputs=output_schema)

# Start an MLflow run
with mlflow.start_run() as run:
  params = {
      "epochs": epochs,
      "learning_rate": 1e-3,
      "batch_size": 64,
      "loss_function": loss_fn.__class__.__name__,
      "metric_function": metric_fn.__class__.__name__,
      "optimizer": "SGD",
  }
  # Log training parameters.
  mlflow.log_params(params)

  # Log model summary
  with open('model_summary.txt', "w", encoding="utf-8") as f:
      f.write(str(summary(model)))
  mlflow.log_artifact('model_summary.txt')  

  for t in range(epochs):
      print(f"Epoch {t + 1}-------------------------------")
      train(train_dataloader, model, loss_fn, metric_fn, optimizer, epoch=t)
      evaluate(test_dataloader, model, loss_fn, metric_fn, epoch=0)

  # Save the trained model to MLflow.
  mlflow.pytorch.log_model(model, "model", signature=signature)
# Out:
# Epoch 1-------------------------------
# loss: 0.447348 accuracy: 0.812500 [0 / 938]
# loss: 0.569907 accuracy: 0.734375 [100 / 938]
# loss: 0.374351 accuracy: 0.859375 [200 / 938]
# loss: 0.650207 accuracy: 0.765625 [300 / 938]
# loss: 0.581302 accuracy: 0.703125 [400 / 938]
# loss: 0.580364 accuracy: 0.796875 [500 / 938]
# loss: 0.576874 accuracy: 0.765625 [600 / 938]
# loss: 0.619337 accuracy: 0.796875 [700 / 938]
# loss: 0.674312 accuracy: 0.734375 [800 / 938]
# loss: 0.526939 accuracy: 0.796875 [900 / 938]
# Eval metrics: Accuracy: 0.79, Avg loss: 0.572654
# Epoch 2-------------------------------
# loss: 0.436815 accuracy: 0.812500 [0 / 938]
# loss: 0.546893 accuracy: 0.734375 [100 / 938]
# loss: 0.361582 accuracy: 0.859375 [200 / 938]
# loss: 0.624199 accuracy: 0.781250 [300 / 938]
# loss: 0.568069 accuracy: 0.703125 [400 / 938]
# loss: 0.562512 accuracy: 0.781250 [500 / 938]
# loss: 0.554829 accuracy: 0.796875 [600 / 938]
# loss: 0.616821 accuracy: 0.812500 [700 / 938]
# loss: 0.680242 accuracy: 0.750000 [800 / 938]
# loss: 0.501944 accuracy: 0.796875 [900 / 938]
# Eval metrics: Accuracy: 0.79, Avg loss: 0.566221
# Epoch 3-------------------------------
# loss: 0.432622 accuracy: 0.828125 [0 / 938]
# loss: 0.528732 accuracy: 0.750000 [100 / 938]
# loss: 0.353905 accuracy: 0.859375 [200 / 938]
# loss: 0.603653 accuracy: 0.765625 [300 / 938]
# loss: 0.556090 accuracy: 0.718750 [400 / 938]
# loss: 0.546617 accuracy: 0.781250 [500 / 938]
# loss: 0.538342 accuracy: 0.812500 [600 / 938]
# loss: 0.614503 accuracy: 0.796875 [700 / 938]
# loss: 0.684131 accuracy: 0.750000 [800 / 938]
# loss: 0.483466 accuracy: 0.812500 [900 / 938]
# 2025/05/09 21:32:49 WARNING mlflow.utils.requirements_utils: Found torch version (2.7.0+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.7.0' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# Eval metrics: Accuracy: 0.79, Avg loss: 0.561819
# 2025/05/09 21:32:54 WARNING mlflow.utils.requirements_utils: Found torch version (2.7.0+cu128) contains a local version label (+cu128). MLflow logged a pip requirement for this package as 'torch==2.7.0' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.

# %% [markdown]
# ### Register the model

# %%
model_uri = f"runs:/{run.info.run_id}/model"
mv = mlflow.register_model(model_uri, "CNNModel")
print(f"Name: {mv.name}")
print(f"Version: {mv.version}")
# Out:
# Name: CNNModel
# Version: 2
# Registered model 'CNNModel' already exists. Creating a new version of this model...
# Created version '2' of model 'CNNModel'.

# %% [markdown]
# ### Stop the MLFlow Tracking Server

# %%
# Run the following commands on the Terminal
netstat -ano | findstr : <8081>
taskkill /PID <12548> /F
